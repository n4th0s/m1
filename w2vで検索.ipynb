# %%
import gensim
import srsql
import pandas as pd
from tqdm.auto import tqdm
from statistics import harmonic_mean
from scipy import stats

# %%
from gensim.models import KeyedVectors

# %%
mo = '800^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '800^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '800^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '400^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '400^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '400^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '200^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '200^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
mo = '200^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
model.wv.save(mo + '.kv')

# %%
pa_term = "iot"
wv = KeyedVectors.load('800^12.kv', mmap='r')
df_mo = wv.most_similar(pa_term, topn=3000)

# %%
wv = KeyedVectors.load('800^8.kv', mmap='r')
df_mo1 = wv.most_similar(pa_term, topn=3000)

# %%
df_mo
# Out:
# [('iiot', 0.5322252511978149),
#  ('machine-to-machine', 0.45970651507377625),
#  ('m0m', 0.4544069468975067),
#  ('connected', 0.43066608905792236),
#  ('wearables', 0.379261314868927),
#  ('internet-of-things', 0.3760978579521179),
#  ('smart', 0.3745143711566925),
#  ('connectivity', 0.3673448860645294),
#  ('wi-fi', 0.34147390723228455),
#  ('lpwan', 0.3295593559741974),
#  ('computing', 0.3259803354740143),
#  ('intelligent', 0.3249239921569824),
#  ('nb-iot', 0.3225932717323303),
#  ('software-defined', 0.3136031925678253),
#  ('zigbee', 0.31333670020103455),
#  ('smartphones', 0.3037603497505188),
#  ('wlan', 0.2996025085449219),
#  ('wireless', 0.2995407283306122),
#  ('calamp', 0.2990680932998657),
#  ('always-on', 0.2974165081977844),
#  ('automation', 0.29608669877052307),
#  ('sigfox', 0.29605555534362793),
#  ('smartwatches', 0.29582151770591736),
#  ('nimbelink', 0.29450106620788574),
#  ('wearable', 0.29348286986351013),
#  ('mobile', 0.2933759093284607),
# ...

# %%
# EV
# game & e-sports
# medical device
# edtech
# cloud-computing
# social-media
# internet-of-things
# fintech
# clean-water
pa_term = "iot"

# %%
mo = '800^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo = pd.DataFrame(word, columns=['word', mo])

# %%
mo = '800^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '800^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(pa_term, topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
df_mo["score"] = 0
for i in range(len(df_mo)):
    df_mo.iloc[i, 10] = stats.hmean(df_mo.iloc[i, 1:9])

# %%
df_mo.to_csv("result/" + pa_term + "_score.csv", index=False)

# %%
df_mo = df_mo.head(500)

# %%
w_list = list(df_mo["word"])

# %%
df_mo = pd.read_csv("result/" + pa_term + "_score.csv")

# %%
df_mo
# Out:
#                    word    800^12     800^8     800^4    400^12     400^8  \
# 0                  iiot  0.532225  0.529235  0.564278  0.629739  0.662403
# 1    machine-to-machine  0.459707  0.459443  0.442436  0.532473  0.549635
# 2                   m0m  0.454407  0.467153  0.506424  0.535511  0.569259
# 3             connected  0.430666  0.420186  0.432156  0.560594  0.557856
# 4             wearables  0.379261  0.385568  0.403598  0.444641  0.465547
# ..                  ...       ...       ...       ...       ...       ...
# 619            wideband  0.153128  0.200111  0.283376  0.236510  0.228098
# 620                 wsn  0.153062  0.175601  0.254786  0.275020  0.266462
# 621            e-series  0.152942  0.203552  0.259497  0.217106  0.276385
# 622                csps  0.152933  0.180776  0.222699  0.249486  0.307273
# 623             edgemax  0.151801  0.234664  0.286669  0.242574  0.310063
#
#         400^4    200^12     200^8     200^4     score
# ...

# %% [markdown]
# # sql

# %% [markdown]
# ## F10に登場する単語

# %%
connection = srsql.srsql('10years')
sql = "SELECT * FROM word_list"
with connection:
    with connection.cursor() as cur:
        cur.execute(sql, ())
        c_result = cur.fetchall()
df = pd.DataFrame(c_result)

# %% [markdown]
# ## 単語-回数-企業

# %%
connection = srsql.srsql('10years')
sql = "SELECT * FROM count"
with connection:
    with connection.cursor() as cur:
        cur.execute(sql, ())
        c_result = cur.fetchall()
df_c = pd.DataFrame(c_result)

# %% [markdown]
# ## 企業-総単語数

# %%
# connection = srsql.srsql('10years')
# sql = "SELECT * FROM company"
# with connection:
#     with connection.cursor() as cur:
#         cur.execute(sql, ())
#         c_result = cur.fetchall()
# df_sum = pd.DataFrame(c_result)

# %%
connection = srsql.srsql('10years')
sql = "SELECT * FROM count inner join company on count.company = company.company"
with connection:
    with connection.cursor() as cur:
        cur.execute(sql, ())
        c_result = cur.fetchall()
df_s = pd.DataFrame(c_result)

# %%
del c_result

# %% [markdown]
# # 指定単語で検索

# %% [markdown]
# ## 単語を指定してください

# %%
# EV
# game & e-sports
# medical device
# edtech
# cloud-computing
# social-media
# internet-of-things
# fintech
pa_term = "internet-of-things"

# %% [markdown]
# ## 実行

# %% [markdown]
# word = model.wv.most_similar(pa_term, topn=2000)

# %% [markdown]
# num = 0
# w_list = []
# for i in tqdm(range(len(word))):
#     a = word[i]
#     b = a[0] in df.values
#     if b == True:
#         num += 1
#         w_list.append(a)
#         if num >= 500:
#             break

# %%
# 親単語が出てくる企業
i = pa_term in df_s.values
if i == True:
    parents = df_s[df_s["word"] == pa_term]
parents.set_axis(list(parents["company"]), inplace=True)

# %%
parents
# Out:
#         word  count  company    id company.company      sum
# A.N      iot      7      A.N  2753             A.N  4145928
# AACI.OQ  iot      1  AACI.OQ  3249         AACI.OQ     5859
# ADBE.OQ  iot      2  ADBE.OQ  4292         ADBE.OQ   101111
# ADSK.OQ  iot      5  ADSK.OQ   228         ADSK.OQ    83029
# ADTN.OQ  iot      5  ADTN.OQ  4108         ADTN.OQ    71269
# ...      ...    ...      ...   ...             ...      ...
# ZI.OQ    iot      2    ZI.OQ  1610           ZI.OQ   142263
# ZS.OQ    iot      6    ZS.OQ  2556           ZS.OQ    30519
# ZUO.N    iot      3    ZUO.N  1581           ZUO.N    21047
# CTSH.OQ  iot     19  CTSH.OQ  4742         CTSH.OQ    80045
# O.N      iot     20      O.N  4754             O.N  4411464
#
# [369 rows x 6 columns]

# %%
asdf = pd.DataFrame()

# %%
for i in tqdm(w_list):
    asdf = pd.concat([asdf, df_s[df_s["word"] == i] ])# 子単語が出てくる企業
#     kids.set_axis(list(kids["company"]), inplace=True)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
asdf = asdf.drop(columns=['id', 'company.company', 'sum'])

# %%
asdf_i = asdf.set_index('word')
asdf_i
# Out:
#                  count  company
# word
# iiot                28  AIRG.OQ
# iiot                 1  ANSS.OQ
# iiot                47  BSQR.OQ
# iiot                 1      C.N
# iiot                 6  CASA.OQ
# ...                ...      ...
# microelectronic     14     UA.N
# microelectronic      5      V.N
# microelectronic     23  VECO.OQ
# microelectronic      8      Y.N
# microelectronic      9      O.N
#
# [95006 rows x 2 columns]

# %%
parents_comp = set(list(parents['company']))
kids_comp = set(list(asdf_i['company']))
sb = len(parents_comp & kids_comp) / len(kids_comp)

# %%
tf = pd.DataFrame()
for i in tqdm(kids_comp):
    t = asdf_i[asdf_i['company'] == i]['count'] / asdf_i[asdf_i['company'] == i]['count'].sum()
    t = pd.DataFrame(t)
    t['comp'] = i
    tf = pd.concat([tf, t])
tf
# Out:
#   0%|          | 0/4746 [00:00<?, ?it/s]
#                    count     comp
# word
# solutions       0.012270  SBTX.OQ
# technologies    0.110429  SBTX.OQ
# technology      0.294479  SBTX.OQ
# applications    0.276074  SBTX.OQ
# internet        0.012270  SBTX.OQ
# ...                  ...      ...
# video           0.010417  ROST.OQ
# internet        0.114583  ROST.OQ
# infrastructure  0.083333  ROST.OQ
# platform        0.104167  ROST.OQ
# networks        0.010417  ROST.OQ
#
# [95006 rows x 2 columns]

# %%
sa = df_mo.set_index('word')['score']
fs = sa * 2 * sb / (sa + sb)

# %%
tf[tf.index == 'iiot']
# Out:
#          count     comp
# word
# iiot  0.003030    FLS.N
# iiot  0.000077      D.N
# iiot  0.001130    DDD.N
# iiot  0.005602  PCTI.OQ
# iiot  0.004098    LNN.N
# iiot  0.001698   ENG.OQ
# iiot  0.004839    EMR.N
# iiot  0.007392    DOV.N
# iiot  0.002141   KORE.N
# iiot  0.001764  SGLB.OQ
# iiot  0.000805  OESX.OQ
# iiot  0.000691     DD.N
# iiot  0.002075  CASA.OQ
# iiot  0.001790  PRGS.OQ
# iiot  0.000201    VHC.N
# iiot  0.000423  CDNS.OQ
# iiot  0.000435  ANSS.OQ
# iiot  0.017885  ITRI.OQ
# iiot  0.000484     MG.N
# iiot  0.001116     IR.N
# iiot  0.001210  INPX.OQ
# iiot  0.000455      V.N
# iiot  0.011209  CMBM.OQ
# iiot  0.004174    ZWS.N
# iiot  0.008090  AIRG.OQ
# iiot  0.001238    GH.OQ
# iiot  0.000185      R.N
# iiot  0.000018      C.N
# iiot  0.002042   SGH.OQ
# iiot  0.000230     RE.N
# iiot  0.000346      G.N
# iiot  0.001985  FCUV.OQ
# iiot  0.000983   CHX.OQ
# iiot  0.017037   PTC.OQ
# iiot  0.007352  INSG.OQ
# iiot  0.017636  BSQR.OQ
# iiot  0.000693      J.N

# %%
k1 = 2
b1 = 0.75
CS = pd.DataFrame()
d1 = []
for i in tqdm(w_list): # iが対象としている子単語
    sa = df_mo.set_axis(df_mo["word"]).loc[i, 'score']
    kids = df_s[df_s["word"] == i] # 子単語が出てくる企業
    kids.set_axis(list(kids["company"]), inplace=True)
#     if len(list(kids["company"])) == 0:
#         d1.append(i)
#         continue
#     else:
#         sb = len(set(list(parents["company"])) & set(list(kids["company"]))) / len(list(kids["company"])) # sb
#         fs = (2 * sa * sb) / (sa + sb) # fs
#         tf = kids["count"] / kids["sum"]
#         avg_dl = kids["sum"].sum() / len(list(kids["sum"]))
#         cs = fs * tf * (k1 + 1) / (tf + k1 * (1 - b1 + b1 * tf / avg_dl)) # 
#         CS = pd.concat([CS, cs], axis=1)
#         CS.rename(columns = {0 : i}, inplace = True)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <cell line: 5>()
#       5 for i in tqdm(w_list): # iが対象としている子単語
#       6     sa = df_mo.set_axis(df_mo["word"]).loc[i, 'score']
# ----> 7     kids = df_s[df_s["word"] == i] # 子単語が出てくる企業
#       8     kids.set_axis(list(kids["company"]), inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
sa
# Out:
# 0.3601944467458069

# %% [markdown]
# ## 対象単語保存

# %%
# w2v_score = pd.DataFrame(w_list, columns=['word', 'w2v'])

# %%
# w2v_score.to_csv("result/" + pa_term + "_w2v.csv", index=False)

# %% [markdown]
# ## 保存

# %%
# os.chdir("C:\\Users\\SR\\python\\m1\\similarity\\")
CS.to_csv("result/" + pa_term + ".csv")

# %% [markdown]
# ## 企業ランク付け

# %%
CS = CS.sum(axis=1).sort_values(ascending=False)

# %%
# 保存
CS.to_csv("result/" + pa_term + "_sum.csv")

# %% [markdown]
# # andとor検索(共通部分と全て)

# %%
# cloud computing
# social media
# internet things
# finance technology
# clean water
# sewer water
p1 = "iot"
p2 = "cloud"

# %%
mo = '800^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo = pd.DataFrame(word, columns=['word', mo])

# %%
mo = '800^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '800^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '400^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^12'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^8'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
mo = '200^4'
model = gensim.models.Word2Vec.load('models/model_10_' + mo + '.bin')
word = model.wv.most_similar(positive=[p1, p2], topn=3000)
df_mo1 = pd.DataFrame(word, columns=['word', mo])
df_mo = pd.merge(df_mo, df_mo1, on='word')

# %%
df_mo["score"] = 0
for i in range(len(df_mo)):
    df_mo.iloc[i, 10] = stats.hmean(df_mo.iloc[i, 1:10])

# %%
df_mo.to_csv("result/" + p1 + '_' + p2 + "_score.csv", index=False)

# %%
df_mo = df_mo.head(500)

# %%
w_list = list(df_mo["word"])

# %%
# 親単語1が出てくる企業
i = p1 in df_s.values
if i == True:
    parents1 = df_s[df_s["word"] == p1]
parents1.set_axis(list(parents1["company"]), inplace=True)

# %%
# 親単語2が出てくる企業
i = p2 in df_s.values
if i == True:
    parents2 = df_s[df_s["word"] == p2]
parents2.set_axis(list(parents2["company"]), inplace=True)

# %%
parents = set(list(set(parents1["company"]) & set(parents2["company"])))

# %%
k1 = 2
b1 = 0.75
CS = pd.DataFrame()
d1 = []
for i in tqdm(w_list): # 対象としている子単語
    sa = df_mo.set_axis(df_mo["word"]).loc[i, 'score'] # 子単語のw2vスコア
    kids = df_s[df_s["word"] == i] # 子単語が出てくる企業
    kids.set_axis(list(kids["company"]), inplace=True)
    j = len(list(kids["company"]))
    if j == 0:
        d1.append(i)
        continue
    else:
        sb = len(parents & set(list(kids["company"]))) / j # sb
        fs = (2 * sa * sb) / (sa + sb) # fs
        tf = kids["count"] / kids["sum"]
        avg_dl = kids["sum"].sum() / len(list(kids["sum"]))
        cs = fs * tf * (k1 + 1) / (tf + k1 * (1 - b1 + b1 * tf / avg_dl)) # 
        CS = pd.concat([CS, cs], axis=1)
        CS.rename(columns = {0 : i}, inplace = True)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
CS
# for i in tqdm(w_list): # iが対象としている子単語
#     sa = df_mo.set_axis(df_mo["word"]).loc[i, 'score']
#     kids = df_s[df_s["word"] == i] # 子単語が出てくる企業
#     kids.set_axis(list(kids["company"]), inplace=True)
#     if len(list(kids["company"])) == 0:
#         d1.append(i)
#         continue
#     else:
#         sb = len(set(list(parents["company"])) & set(list(kids["company"]))) / len(list(kids["company"])) # sb
#         fs = (2 * sa * sb) / (sa + sb) # fs
#         tf = kids["count"] / kids["sum"]
#         avg_dl = kids["sum"].sum() / len(list(kids["sum"]))
#         cs = fs * tf * (k1 + 1) / (tf + k1 * (1 - b1 + b1 * tf / avg_dl)) # 
#         CS = pd.concat([CS, cs], axis=1)
#         CS.rename(columns = {0 : i}, inplace = True)
# Out:
#          wastewater     sewer       air  showerheads  aquifers  unpolluted  \
# A.N        0.000225  0.000008  0.000586          NaN  0.000007         NaN
# ABG.N      0.000105       NaN  0.000425          NaN       NaN         NaN
# ABMD.OQ    0.000048       NaN  0.000035          NaN       NaN         NaN
# AC.N       0.000007       NaN  0.000228          NaN       NaN         NaN
# ACM.N      0.000693  0.000035  0.000509          NaN       NaN         NaN
# ...             ...       ...       ...          ...       ...         ...
# TSRI.OQ         NaN       NaN       NaN          NaN       NaN         NaN
# UDMY.OQ         NaN       NaN       NaN          NaN       NaN         NaN
# CHMI.N          NaN       NaN       NaN          NaN       NaN         NaN
# CDR.N           NaN       NaN       NaN          NaN       NaN         NaN
# CODX.OQ         NaN       NaN       NaN          NaN       NaN         NaN
#
# ...

# %%
d1
# Out:
# ['spring-fed',
#  'subbasin',
#  'biofilters',
#  'water-rich',
#  'swimmable',
#  'fishable',
#  'clarifier',
#  'turbid',
#  'waist-deep',
#  'srwtp',
#  'nerodia',
#  'inflowing',
#  'mwra',
#  'eichhornia',
#  'standpipes',
#  'undammed',
#  'milfoil',
#  'periphyton',
#  'deaerator',
#  'percolates',
#  'bay-delta',
#  'well-oxygenated',
#  'bioswales',
#  'ponding',
#  'sabkha',
#  'warm-water',
#  'cfc-0',
#  'hardpan',
#  'cesspools',
#  'composted',
#  'rivulets',
#  'slow-flowing',
#  'bioswale',
#  'sea-water',
#  'biohydrogen',
#  'bubbling',
#  'hetchy',
#  'gushes',
#  'surface-water',
#  'cattails',
#  'phreatic',
#  'oxygen-depleted',
#  'sodis',
#  'hetch',
#  'water-conserving',
#  'well-aerated',
#  'hypersaline',
#  'deionised',
#  'vegetated',
#  'floridan',
#  'tmdls',
#  'lakebed',
#  'overdrafting',
#  'macrophyte',
#  'damming',
#  'reticulation',
#  'kemano',
#  'hydroelectrical',
#  'ever-flowing',
#  'julimes',
#  'pressurised',
#  'fetid',
#  'soakage',
# ...

# %% [markdown]
# ## 保存

# %%
CS.to_csv("result/" + p1 + '_and_' + p2 + ".csv")

# %%
CS = CS.sum(axis=1).sort_values(ascending=False)
CS.to_csv("result/" + p1 + '_and_' + p2 + "_sum.csv")

# %% [markdown]
# # or検索(すべて)

# %%
parents = set(list(set(parents1["company"]) | set(parents2["company"])))

# %%
k1 = 2
b1 = 0.75
CS = pd.DataFrame()
d1 = []
for i in tqdm(w_list): # 対象としている子単語
    sa = df_mo.set_axis(df_mo["word"]).loc[i, 'score'] # 子単語のw2vスコア
    kids = df_s[df_s["word"] == i] # 子単語が出てくる企業
    kids.set_axis(list(kids["company"]), inplace=True)
    j = len(list(kids["company"]))
    if j == 0:
        d1.append(i)
        continue
    else:
        sb = len(parents & set(list(kids["company"]))) / j # sb
        fs = (2 * sa * sb) / (sa + sb) # fs
        tf = kids["count"] / kids["sum"]
        avg_dl = kids["sum"].sum() / len(list(kids["sum"]))
        cs = fs * tf * (k1 + 1) / (tf + k1 * (1 - b1 + b1 * tf / avg_dl)) # 
        CS = pd.concat([CS, cs], axis=1)
        CS.rename(columns = {0 : i}, inplace = True)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
CS.to_csv("result/" + p1 + '_or_' + p2 + ".csv")

# %%
CS = CS.sum(axis=1).sort_values(ascending=False)
CS.to_csv("result/" + p1 + '_or_' + p2 + "_sum.csv")

# %%
print(model.wv.most_similar(positive=["medical", "device"], topn=100))
# Out:
# [('devices', 0.5779680609703064), ('drug', 0.4292638599872589), ('fda', 0.41546204686164856), ('clinical', 0.37683093547821045), ('health', 0.3644098937511444), ('patient', 0.356537789106369), ('healthcare', 0.3549816906452179), ('care', 0.350808709859848), ('pre-market', 0.34761953353881836), ('pharmaceutical', 0.34231051802635193), ('cystoscope', 0.3367888629436493), ('drugs', 0.33631646633148193), ('sc0wear', 0.32953161001205444), ('intra-arterial', 0.32838937640190125), ('implanted', 0.3254612982273102), ('infusor', 0.321833074092865), ('arc-certified', 0.3217856287956238), ('orthotic', 0.3216426372528076), ('prostheses', 0.31974145770072937), ('premarket', 0.3192136883735657), ('sterilant', 0.31805387139320374), ('cardioverter-defibrillator', 0.3176380693912506), ('iatrogenic', 0.3163701891899109), ('indwelling', 0.3152884244918823), ('radiologic', 0.3140755295753479), ('diagnostic', 0.31393149495124817), ('ce-mark', 0.31136205792427063), ('radiographer', 0.3111127018928528), ('
# ...

# %%
pa1 = 'medical'
pa2 = 'device'

# %%
word = model.wv.most_similar(pa1, topn=2000)

# %%
word2 = model.wv.most_similar(pa2, topn=2000)

# %%
# どっちかに出てくる単語（or）用

# %%
word.extend(word2)

# %%
word = sorted(word, key=lambda x: float(x[1]), reverse=True)
# w_list作成の場所に戻ってください

# %%
w2v_score = pd.DataFrame(w_list, columns=['word', 'w2v'])
w2v_score.to_csv("result/" + pa1 + '-' + pa2 + "_or_w2v.csv", index=False)

# %%
# どっちにも出てくる単語（and）用

# %%
word = pd.DataFrame(word, columns=['word', 'w2v'])
word2 = pd.DataFrame(word2, columns=['word', 'w2v'])

# %%
word2 = pd.merge(word, word2, on='word', how='inner', suffixes=['_medical', '_device'])

# %%
word = list(word2['word'])

# %%
# 上の方でw_list作ってきてください

# %%
w_list = pd.DataFrame(w_list, columns=['word'])

# %%
pd.merge(word2, w_list, on='word', how='inner').to_csv("result/" + pa1 + '-' + pa2 + "_and_w2v.csv", index=False)
